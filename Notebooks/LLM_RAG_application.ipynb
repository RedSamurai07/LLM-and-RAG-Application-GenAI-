# %%
import numpy as np
import pandas as pd
import time
import logging
import matplotlib.pyplot as plt
from typing import List, Dict
from dataclasses import dataclass, field
from datetime import datetime
from datasets import load_dataset
import warnings
warnings.filterwarnings('ignore')

# %%
# %pip install langchain langchain-community chromadb
# %pip install datasets langchain chromadb sentence-transformers rank-bm25 pymupdf
# Out:
# Requirement already satisfied: langchain in d:\Documents\anaconda\Lib\site-packages (1.2.10)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: langchain-community in d:\Documents\anaconda\Lib\site-packages (0.4.1)
# Requirement already satisfied: chromadb in d:\Documents\anaconda\Lib\site-packages (1.5.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in d:\Documents\anaconda\Lib\site-packages (from langchain) (1.2.17)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in d:\Documents\anaconda\Lib\site-packages (from langchain) (1.0.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\Documents\anaconda\Lib\site-packages (from langchain) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\Documents\anaconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\Documents\anaconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.11)
# Requirement already satisfied: packaging>=23.2.0 in d:\Documents\anaconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\Documents\anaconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\Documents\anaconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\Documents\anaconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.12.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\Documents\anaconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\Documents\anaconda\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (2.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in d:\Documents\anaconda\Lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in d:\Documents\anaconda\Lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in d:\Documents\anaconda\Lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.9)
# Requirement already satisfied: xxhash>=3.5.0 in d:\Documents\anaconda\Lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in d:\Documents\anaconda\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in d:\Documents\anaconda\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in d:\Documents\anaconda\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\Documents\anaconda\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\Documents\anaconda\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\Documents\anaconda\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.23.0)
# Requirement already satisfied: anyio in d:\Documents\anaconda\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (4.7.0)
# Requirement already satisfied: certifi in d:\Documents\anaconda\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in d:\Documents\anaconda\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.0.9)
# Requirement already satisfied: idna in d:\Documents\anaconda\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.7)
# Requirement already satisfied: h11>=0.16 in d:\Documents\anaconda\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\Documents\anaconda\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in d:\Documents\anaconda\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in d:\Documents\anaconda\Lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in d:\Documents\anaconda\Lib\site-packages (from langchain-community) (2.0.39)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\Documents\anaconda\Lib\site-packages (from langchain-community) (3.11.10)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in d:\Documents\anaconda\Lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in d:\Documents\anaconda\Lib\site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\Documents\anaconda\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in d:\Documents\anaconda\Lib\site-packages (from langchain-community) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\Documents\anaconda\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\Documents\anaconda\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\Documents\anaconda\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\Documents\anaconda\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\Documents\anaconda\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\Documents\anaconda\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\Documents\anaconda\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.18.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\Documents\anaconda\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\Documents\anaconda\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in d:\Documents\anaconda\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\Documents\anaconda\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\Documents\anaconda\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\Documents\anaconda\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\Documents\anaconda\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in d:\Documents\anaconda\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\Documents\anaconda\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: build>=1.0.3 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pybase64>=1.4.1 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in d:\Documents\anaconda\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.41.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (1.24.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in d:\Documents\anaconda\Lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: six>=1.5 in d:\Documents\anaconda\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in d:\Documents\anaconda\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in d:\Documents\anaconda\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in d:\Documents\anaconda\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: pyproject_hooks in d:\Documents\anaconda\Lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in d:\Documents\anaconda\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\Documents\anaconda\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\Documents\anaconda\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\Documents\anaconda\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\Documents\anaconda\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in d:\Documents\anaconda\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in d:\Documents\anaconda\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in d:\Documents\anaconda\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in d:\Documents\anaconda\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.5)
# Requirement already satisfied: sympy in d:\Documents\anaconda\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in d:\Documents\anaconda\Lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in d:\Documents\anaconda\Lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in d:\Documents\anaconda\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in d:\Documents\anaconda\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in d:\Documents\anaconda\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in d:\Documents\anaconda\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\Documents\anaconda\Lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\Documents\anaconda\Lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in d:\Documents\anaconda\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in d:\Documents\anaconda\Lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.4.1)
# Requirement already satisfied: filelock in d:\Documents\anaconda\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\Documents\anaconda\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in d:\Documents\anaconda\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: shellingham in d:\Documents\anaconda\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.0)
# Requirement already satisfied: typer-slim in d:\Documents\anaconda\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (0.21.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\Documents\anaconda\Lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: httptools>=0.6.3 in d:\Documents\anaconda\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in d:\Documents\anaconda\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in d:\Documents\anaconda\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in d:\Documents\anaconda\Lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\Documents\anaconda\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\Documents\anaconda\Lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: datasets in d:\Documents\anaconda\Lib\site-packages (4.5.0)
# Requirement already satisfied: langchain in d:\Documents\anaconda\Lib\site-packages (1.2.10)
# Requirement already satisfied: chromadb in d:\Documents\anaconda\Lib\site-packages (1.5.2)
# Requirement already satisfied: sentence-transformers in d:\Documents\anaconda\Lib\site-packages (5.2.3)
# Requirement already satisfied: rank-bm25 in d:\Documents\anaconda\Lib\site-packages (0.2.2)
# Requirement already satisfied: pymupdf in d:\Documents\anaconda\Lib\site-packages (1.27.1)
# Requirement already satisfied: filelock in d:\Documents\anaconda\Lib\site-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in d:\Documents\anaconda\Lib\site-packages (from datasets) (2.1.3)
# Requirement already satisfied: pyarrow>=21.0.0 in d:\Documents\anaconda\Lib\site-packages (from datasets) (23.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in d:\Documents\anaconda\Lib\site-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in d:\Documents\anaconda\Lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in d:\Documents\anaconda\Lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in d:\Documents\anaconda\Lib\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in d:\Documents\anaconda\Lib\site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in d:\Documents\anaconda\Lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in d:\Documents\anaconda\Lib\site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in d:\Documents\anaconda\Lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.3.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in d:\Documents\anaconda\Lib\site-packages (from datasets) (1.4.1)
# Requirement already satisfied: packaging in d:\Documents\anaconda\Lib\site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\Documents\anaconda\Lib\site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in d:\Documents\anaconda\Lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.11.10)
# Requirement already satisfied: anyio in d:\Documents\anaconda\Lib\site-packages (from httpx<1.0.0->datasets) (4.7.0)
# Requirement already satisfied: certifi in d:\Documents\anaconda\Lib\site-packages (from httpx<1.0.0->datasets) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in d:\Documents\anaconda\Lib\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in d:\Documents\anaconda\Lib\site-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: h11>=0.16 in d:\Documents\anaconda\Lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in d:\Documents\anaconda\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: shellingham in d:\Documents\anaconda\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.0)
# Requirement already satisfied: typer-slim in d:\Documents\anaconda\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in d:\Documents\anaconda\Lib\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.12.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in d:\Documents\anaconda\Lib\site-packages (from langchain) (1.2.17)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in d:\Documents\anaconda\Lib\site-packages (from langchain) (1.0.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\Documents\anaconda\Lib\site-packages (from langchain) (2.10.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\Documents\anaconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\Documents\anaconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.11)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\Documents\anaconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.0.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\Documents\anaconda\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\Documents\anaconda\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (2.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in d:\Documents\anaconda\Lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in d:\Documents\anaconda\Lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in d:\Documents\anaconda\Lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.9)
# Requirement already satisfied: ormsgpack>=1.12.0 in d:\Documents\anaconda\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in d:\Documents\anaconda\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\Documents\anaconda\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\Documents\anaconda\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\Documents\anaconda\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in d:\Documents\anaconda\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: build>=1.0.3 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pybase64>=1.4.1 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in d:\Documents\anaconda\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.41.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (1.24.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in d:\Documents\anaconda\Lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in d:\Documents\anaconda\Lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: six>=1.5 in d:\Documents\anaconda\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in d:\Documents\anaconda\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in d:\Documents\anaconda\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in d:\Documents\anaconda\Lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\Documents\anaconda\Lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\Documents\anaconda\Lib\site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in d:\Documents\anaconda\Lib\site-packages (from sentence-transformers) (5.1.0)
# Requirement already satisfied: torch>=1.11.0 in d:\Documents\anaconda\Lib\site-packages (from sentence-transformers) (2.7.1+cu118)
# Requirement already satisfied: scikit-learn in d:\Documents\anaconda\Lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in d:\Documents\anaconda\Lib\site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: regex!=2019.12.17 in d:\Documents\anaconda\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in d:\Documents\anaconda\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\Documents\anaconda\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\Documents\anaconda\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\Documents\anaconda\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\Documents\anaconda\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\Documents\anaconda\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\Documents\anaconda\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\Documents\anaconda\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.18.0)
# Requirement already satisfied: pyproject_hooks in d:\Documents\anaconda\Lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in d:\Documents\anaconda\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\Documents\anaconda\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\Documents\anaconda\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\Documents\anaconda\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\Documents\anaconda\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in d:\Documents\anaconda\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in d:\Documents\anaconda\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in d:\Documents\anaconda\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in d:\Documents\anaconda\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.5)
# Requirement already satisfied: sympy in d:\Documents\anaconda\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in d:\Documents\anaconda\Lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in d:\Documents\anaconda\Lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in d:\Documents\anaconda\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in d:\Documents\anaconda\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in d:\Documents\anaconda\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in d:\Documents\anaconda\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\Documents\anaconda\Lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\Documents\anaconda\Lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in d:\Documents\anaconda\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: networkx in d:\Documents\anaconda\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in d:\Documents\anaconda\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in d:\Documents\anaconda\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\Documents\anaconda\Lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\Documents\anaconda\Lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: httptools>=0.6.3 in d:\Documents\anaconda\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in d:\Documents\anaconda\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: watchfiles>=0.20 in d:\Documents\anaconda\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in d:\Documents\anaconda\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in d:\Documents\anaconda\Lib\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\Documents\anaconda\Lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in d:\Documents\anaconda\Lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\Documents\anaconda\Lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\Documents\anaconda\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\Documents\anaconda\Lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\Documents\anaconda\Lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Configuration
CONFIG = {
    "embedding_model": "sentence-transformers/all-MiniLM-L6-v2",
    "dataset_name": "MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1",
    "dense_weight": 0.7,  # RRF Weight for Semantic search
    "top_k": 5}

logging.basicConfig(level=logging.INFO, format="%(asctime)s %(levelname)s %(message)s")
logger = logging.getLogger(__name__)

# %% [markdown]
# ### Data Loading

# %%
def load_markrai_dataset():
    """Loads the 8.5k research corpus nodes and 520 QA test cases."""
    logger.info("Fetching corpus and QA subsets from Hugging Face...")
    corpus_ds = load_dataset(CONFIG['dataset_name'], "corpus", split="train")
    qa_ds = load_dataset(CONFIG['dataset_name'], "qa", split="train")
    
    docs = [{"content": r["contents"], "id": r["doc_id"]} for r in corpus_ds]
    test_set = [{"question": r["query"], "ground_truth": r["generation_gt"][0]} for r in qa_ds]
    
    return docs, test_set

# %% [markdown]
# ### Hybrid Search Engine Architecture

# %%
class HybridSearchEngine:
    """Combines Dense (Embeddings) and Sparse (BM25) for precision."""
    def __init__(self, documents: List[Dict]):
        from sentence_transformers import SentenceTransformer
        from rank_bm25 import BM25Okapi
        
        self.docs = documents
        self.model = SentenceTransformer(CONFIG["embedding_model"])
        self.embeddings = self.model.encode([d["content"] for d in documents], normalize_embeddings=True)
        
        tokenized_corpus = [d["content"].lower().split() for d in documents]
        self.bm25 = BM25Okapi(tokenized_corpus)

    def search(self, query: str, top_k: int = 5) -> List[Dict]:
        # Dense Rank
        q_emb = self.model.encode([query], normalize_embeddings=True)[0]
        dense_ranks = np.argsort(-np.dot(self.embeddings, q_emb))
        
        # Sparse Rank
        bm25_ranks = np.argsort(-self.bm25.get_scores(query.lower().split()))
        
        # Reciprocal Rank Fusion (RRF)
        k = 60
        scores = np.zeros(len(self.docs))
        for rank, idx in enumerate(dense_ranks):
            scores[idx] += CONFIG["dense_weight"] * (1 / (rank + k))
        for rank, idx in enumerate(bm25_ranks):
            scores[idx] += (1 - CONFIG["dense_weight"]) * (1 / (rank + k))
            
        return [dict(self.docs[i], rrf_score=scores[i]) for i in np.argsort(-scores)[:top_k]]

# %% [markdown]
# ### RAG Pipeline and Monitoring

# %%
@dataclass
class RAGResponse:
    query: str
    latency_ms: float
    recall_score: float

class RAGPipeline:
    def __init__(self, engine: HybridSearchEngine):
        self.engine = engine

    def query(self, user_query: str, ground_truth: str) -> RAGResponse:
        t0 = time.time()
        results = self.engine.search(user_query, top_k=CONFIG["top_k"])
        latency = (time.time() - t0) * 1000
        
        # Calculate Context Recall: Does retrieved text contain key GT words?
        context = " ".join([r["content"] for r in results]).lower()
        gt_tokens = set(ground_truth.lower().split())
        recall = sum(1 for t in gt_tokens if t in context) / len(gt_tokens) if gt_tokens else 0
        
        return RAGResponse(query=user_query, latency_ms=latency, recall_score=recall)

# %% [markdown]
# ### Dashboard and Analysis

# %%
def build_monitoring_dashboard(responses: List[RAGResponse]):
    """Generates the FAANG-style performance table and latency summary."""
    df = pd.DataFrame([{
        "Query": r.query[:50] + "...",
        "Recall": f"{r.recall_score:.1%}",
        "Latency (ms)": f"{r.latency_ms:.1f}"
    } for r in responses])
    
    avg_lat = np.mean([r.latency_ms for r in responses])
    avg_recall = np.mean([r.recall_score for r in responses])

    print("\n" + "="*85)
    print(f"{'MARKRAI RAG PERFORMANCE DASHBOARD':^85}")
    print("="*85)
    print(df.to_string(index=False))
    print("-" * 85)
    print(f"AVG LATENCY: {avg_lat:.2f} ms | AVG CONTEXT RECALL: {avg_recall:.2%}")
    print("="*85)

def main():
    docs, tests = load_markrai_dataset()
    engine = HybridSearchEngine(docs)
    pipeline = RAGPipeline(engine)
    
    # Run evaluation on first 10 samples
    results = [pipeline.query(t["question"], t["ground_truth"]) for t in tests[:10]]
    build_monitoring_dashboard(results)

if __name__ == "__main__":
    main()
# Out:
# 2026-03-17 15:17:20,961 INFO Fetching corpus and QA subsets from Hugging Face...
# 2026-03-17 15:17:22,978 INFO HTTP Request: HEAD https://huggingface.co/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# 2026-03-17 15:17:22,993 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/fc10b797869aaa4f8c7f007082d962c507b16fac/README.md "HTTP/1.1 200 OK"
# 2026-03-17 15:17:23,256 INFO HTTP Request: HEAD https://huggingface.co/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/resolve/fc10b797869aaa4f8c7f007082d962c507b16fac/AutoRAG-evaluation-2024-LLM-paper-v1.py "HTTP/1.1 404 Not Found"
# 2026-03-17 15:17:24,042 INFO HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1.py "HTTP/1.1 404 Not Found"
# 2026-03-17 15:17:24,309 INFO HTTP Request: GET https://huggingface.co/api/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/revision/fc10b797869aaa4f8c7f007082d962c507b16fac "HTTP/1.1 200 OK"
# 2026-03-17 15:17:25,016 INFO HTTP Request: HEAD https://huggingface.co/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/resolve/fc10b797869aaa4f8c7f007082d962c507b16fac/.huggingface.yaml "HTTP/1.1 404 Not Found"
# 2026-03-17 15:17:26,595 INFO HTTP Request: GET https://datasets-server.huggingface.co/info?dataset=MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1 "HTTP/1.1 200 OK"
# 2026-03-17 15:17:27,254 INFO HTTP Request: GET https://huggingface.co/api/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/tree/fc10b797869aaa4f8c7f007082d962c507b16fac/qa?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-03-17 15:17:27,500 INFO HTTP Request: GET https://huggingface.co/api/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/tree/fc10b797869aaa4f8c7f007082d962c507b16fac?recursive=false&expand=false "HTTP/1.1 200 OK"
# 2026-03-17 15:17:27,814 INFO HTTP Request: HEAD https://huggingface.co/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/resolve/fc10b797869aaa4f8c7f007082d962c507b16fac/dataset_infos.json "HTTP/1.1 404 Not Found"
# 2026-03-17 15:17:28,083 INFO HTTP Request: GET https://huggingface.co/api/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/tree/fc10b797869aaa4f8c7f007082d962c507b16fac/corpus?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-03-17 15:17:30,202 INFO HTTP Request: HEAD https://huggingface.co/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# 2026-03-17 15:17:31,622 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/fc10b797869aaa4f8c7f007082d962c507b16fac/README.md "HTTP/1.1 200 OK"
# 2026-03-17 15:17:31,875 INFO HTTP Request: HEAD https://huggingface.co/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/resolve/fc10b797869aaa4f8c7f007082d962c507b16fac/AutoRAG-evaluation-2024-LLM-paper-v1.py "HTTP/1.1 404 Not Found"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-03-17 15:17:31,877 WARNING Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-03-17 15:17:32,673 INFO HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1.py "HTTP/1.1 404 Not Found"
# 2026-03-17 15:17:32,926 INFO HTTP Request: HEAD https://huggingface.co/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/resolve/fc10b797869aaa4f8c7f007082d962c507b16fac/.huggingface.yaml "HTTP/1.1 404 Not Found"
# 2026-03-17 15:17:33,196 INFO HTTP Request: GET https://datasets-server.huggingface.co/info?dataset=MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1 "HTTP/1.1 200 OK"
# 2026-03-17 15:17:33,424 INFO HTTP Request: HEAD https://huggingface.co/datasets/MarkrAI/AutoRAG-evaluation-2024-LLM-paper-v1/resolve/fc10b797869aaa4f8c7f007082d962c507b16fac/dataset_infos.json "HTTP/1.1 404 Not Found"
# 2026-03-17 15:17:53,472 INFO Use pytorch device_name: cuda:0
# 2026-03-17 15:17:53,477 INFO Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2026-03-17 15:17:53,783 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-03-17 15:17:54,055 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/modules.json "HTTP/1.1 200 OK"
# 2026-03-17 15:17:55,948 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 2026-03-17 15:17:55,958 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 2026-03-17 15:17:56,218 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 2026-03-17 15:17:56,228 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 2026-03-17 15:17:56,498 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# 2026-03-17 15:17:56,758 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/README.md "HTTP/1.1 200 OK"
# 2026-03-17 15:17:57,027 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-03-17 15:17:57,038 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/modules.json "HTTP/1.1 200 OK"
# 2026-03-17 15:17:57,547 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/sentence_bert_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-03-17 15:17:58,237 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/sentence_bert_config.json "HTTP/1.1 200 OK"
# 2026-03-17 15:18:01,387 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 2026-03-17 15:18:01,648 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-03-17 15:18:01,660 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/config.json "HTTP/1.1 200 OK"
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 2026-03-17 15:18:03,148 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-03-17 15:18:03,418 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/config.json "HTTP/1.1 200 OK"
# 2026-03-17 15:18:04,018 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-03-17 15:18:04,031 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-03-17 15:18:04,307 INFO HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-03-17 15:18:04,567 INFO HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-03-17 15:18:05,398 INFO HTTP Request: HEAD https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2/resolve/main/1_Pooling/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-03-17 15:18:05,411 INFO HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/sentence-transformers/all-MiniLM-L6-v2/c9745ed1d9f207416be6d2e6f8de32d1f16199bf/1_Pooling%2Fconfig.json "HTTP/1.1 200 OK"
# 2026-03-17 15:18:05,657 INFO HTTP Request: GET https://huggingface.co/api/models/sentence-transformers/all-MiniLM-L6-v2 "HTTP/1.1 200 OK"
# Batches:   0%|          | 0/268 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# =====================================================================================
#                           MARKRAI RAG PERFORMANCE DASHBOARD
# =====================================================================================
#                                                 Query Recall Latency (ms)
# Does the Turing Test assess a machine's ability to...   0.0%        283.7
# Is the oa_temp or the zone_occ the most impactful ...  67.9%         73.5
# What is the performance percentage increase observ...  88.9%        122.2
# What are essential components of evaluating large ...  18.8%         64.3
# How many errors were there in the Inference phase ...  62.5%         74.5
# What is the meaning of PLP-former in the context o...  47.4%         71.9
# How does the Qmsum value vary between the first an...   7.4%         79.5
# What is the purpose of using the torch.einsum func...  45.5%        101.2
# What is the result of applying the PAL attack agai...  88.9%        346.9
# What is the process to deceive the test function a...  36.6%        756.0
# -------------------------------------------------------------------------------------
# AVG LATENCY: 197.37 ms | AVG CONTEXT RECALL: 46.37%
# =====================================================================================
